# %% [markdown]
# # Title: DIC: Deep Image Clustering for Unsupervised Image Segmentation
#
# ### Group members
# ####  Name : Akshay kaushik
# ####  Email :200582197@student.georgianc.on.ca
# ####  Name : Dushar
# ####  Email :200582193@student.georgianc.on.ca

# %% [markdown]
# ### INTRODUCTION:
# *********************************************************************************************************************
# #### AIM :
# The project's aim is to create a unsupervised segmentation framework utilizing deep learning techniques, with a particular emphasis on overcoming the shortcomings of existing approaches. The Deep Image Clustering (DIC) model serves as the embodiment of this approach, which attempts to address issues like high computational complexity and parameter sensitivity related to unsupervised segmentation. The DIC model successfully completes unsupervised image clustering by combining a trainable Deep Clustering Subnetwork (DCS) and a Feature Transformation Subnetwork (FTS) by utilizing the adaptability of neural networks. By improving feature aggregation, decreasing sensitivity to segmentation parameters, and cutting computational costs, the research seeks to achieve greater segmentation performance over current methods. The project attempts to confirm the results of intensive testing and analysis on benchmark datasets such as the Berkley Segmentation Database.
# *********************************************************************************************************************
# #### Github Repo:
# https://github.com/zmbhou/DIC/blob/master/demo_DIC_BSD.py
# *********************************************************************************************************************
# #### DESCRIPTION OF PAPER:
# The study presents an unsupervised segmentation method based on a unique Deep Image Clustering (DIC) model. For unsupervised image clustering, this model includes a feature transformation subnetwork (FTS) and a trainable deep clustering subnetwork (DCS). To allocate pixels to distinct clusters, the DCS repeatedly changes cluster allocations and centres. Furthermore, a refinement loss improves the DIC parameters, and experiments on the Berkeley Segmentation Database show that the DIC model is more effective at feature aggregation, less sensitive to segmentation parameters, and produces better segmentation performance than existing methods.
#
# *********************************************************************************************************************
# #### PROBLEM STATEMENT :
# To Overcoming the challenges prevalent in current unsupervised segmentation methods, the approach encounters issues such as parameter sensitivity and high computational demands during both training and inference. In response, a novel Deep Image Clustering (DIC) model is introduced, leveraging the adaptability of neural networks. In achieving successful unsupervised image clustering, the DIC model incorporates a Feature Transformation Subnetwork (FTS) and a trainable Deep Clustering Subnetwork (DCS).
#
# Within the DIC model, the DCS is responsible for assigning pixels varying cluster numbers through iterative updates of cluster relationships and centroids. This methodology enhances feature aggregation throughout the clustering process, leading to improved segmentation outcomes. When benchmarked against state-of-the-art techniques using the Berkley Segmentation Database, the DIC model demonstrates superior performance. Notably, it exhibits reduced sensitivity to segmentation parameter adjustments and offers lower computational overheads, establishing it as a more efficient and effective solution for image segmentation.
# *********************************************************************************************************************
# #### CONTEXT OF THE PROBLEM:
# * In computer vision, unsupervised segmentation is a key method for identifying objects or areas of interest in pictures.
# * The high computational complexity and parameter sensitivity of current unsupervised segmentation algorithms provide challenges  during both training and inference.
# * The study proposes a unique method called Deep picture Clustering (DIC) that makes use of neural networks' adaptability to     tackle problems with unsupervised picture segmentation. DIC is made up of two primary parts: a Trainable Deep Clustering Subnetwork (DCS) and a Feature Transformation Subnetwork  (FTS) intended for image clustering without labelled input.
# *********************************************************************************************************************
# #### SOLUTION:
# * Parameter sensitivity and excessive complexity are problems with unsupervised segmentation in computer vision.Different  segmentation numbers and computing needs are challenges for current approaches.
# * In order to take advantage of the adaptability of neural networks, a unique deep image clustering (DIC) framework is presented. It consists of a trainable deep clustering subnetwork (DCS) and a feature transformation subnetwork (FTS).
# * FTS has a straightforward but efficient network structure. DCS repeatedly changes the cluster centres and assignments, enabling pixels to be a part of several clusters. With this method, feature aggregation is improved.
# * A superpixel-guided iterative refinement loss is used to reduce overfitting and improve DIC settings. The resilience of the model is improved by this method.

# %% [markdown]
# *********************************************************************************************************************
# ## Background
#
#
# | **Reference** | **Explanation** | **Dataset/Input** | **Weakness** |
# |---------------|-----------------|-------------------|--------------|
# | [1] L. Zhou and W. Wei, 2020 | Deep Image Clustering for Unsupervised Image Segmentation | Image data | Lack of empirical results or application to sentiment analysis |
# | [2] T. Kanungo et al., 2002 | Efficient k-means clustering algorithm | Data suitable for clustering | Limited explanation on sentiment analysis or its improvement |
# | [3] C. Carson et al., 2002 | Image segmentation using expectation-maximization | Image data | Focus on image analysis, not sentiment analysis |
# | [4] Jianbo Shi and J. Malik, 2000 | Normalized cuts for image segmentation | Image data | Focused on image analysis, not sentiment analysis |
# | [5] D. Comaniciu and P. Meer, 2002 | Mean shift for feature space analysis | Data suitable for clustering | Limited relevance to sentiment analysis |
# | [6] L. Grady, 2006 | Random Walks for Image Segmentation | Image data | Focus on image analysis, not sentiment analysis |
# | [7] J. Long et al., 2015 | Fully convolutional networks for semantic segmentation | Image data | Focus on image analysis, not sentiment analysis |
# | [8] S. Zheng et al., 2015 | Conditional Random Fields as Recurrent Neural Networks | Data suitable for CRF analysis | Limited discussion on sentiment analysis |
# | [9] L. -C. Chen et al., 2016 | Semantic Image Segmentation with Task-Specific Edge Detection | Image data for semantic segmentation | Limited focus on sentiment analysis |
# | [10] M. Donoser et al., 2009 | Saliency driven total variation segmentation | Image data for segmentation | Limited relevance to sentiment analysis |
# | [11] M. B. Salah et al., 2011 | Multiregion Image Segmentation by Parametric Kernel Graph Cuts | Image data for segmentation | Limited relevance to sentiment analysis |
# | [12] P. Arbeláez et al., 2014 | Multiscale Combinatorial Grouping | Image data for segmentation | Limited relevance to sentiment analysis |
# | [13] X. Fu et al., 2015 | Robust Image Segmentation Using Contour-Guided Color Palettes | Image data for segmentation | Limited relevance to sentiment analysis |
# | [14] Y. LeCun et al., 1989 | Backpropagation Applied to Handwritten Zip Code Recognition | Handwritten digit data | Limited relevance to sentiment analysis |
# | [15] H. Noh et al., 2015 | Learning Deconvolution Network for Semantic Segmentation | Image data for segmentation | Limited relevance to sentiment analysis |
# | [16] W. Song et al., 2019 | Improved U-Net Convolutional Networks for Seabed Mineral Image Segmentation | Image data for segmentation | Limited relevance to sentiment analysis |
# | [17] N. Xu et al., 2016 | Deep Interactive Object Selection | Image data for object selection | Limited relevance to sentiment analysis |
# | [18] K. . -K. Maninis et al., 2018 | Deep Extreme Cut: From Extreme Points to Object Segmentation | Image data for object segmentation | Limited relevance to sentiment analysis |
# | [19] W. -D. Jang and C. -S. Kim, 2019 | Interactive Image Segmentation via Backpropagating Refinement Scheme | Image data for segmentation | Limited relevance to sentiment analysis |
# | [20] V. Lempitsky et al., 2018 | Deep Image Prior | Image data | Limited relevance to sentiment analysis |
#
#
# *********************************************************************************************************************

# %% [markdown]
# *********************************************************************************************************************
# # Implement paper code  :
#
#
# This code appears to be implementing a Deep Clustering Subnetwork (DCS) for image segmentation using a modified UNet architecture. Let's break down the code step by step:
#
# 1. Importing Libraries:
#    - The code starts by importing various necessary libraries, including OpenCV (`cv2`), NumPy (`np`), Scikit-image's segmentation module (`segmentation`), `math`, `torch`, `torch.nn`, and other modules.
#
# 2. Function Definitions:
#    - `denormalizeimage(images, mean, std)`: This function denormalizes tensor images to their original range by reversing the normalization process.
#
# 3. `UNet` Class:
#    - Defines a modified UNet architecture for image segmentation.
#    - Initializes the UNet with an input dimension (`inp_dim`), and two module dimensions (`mod_dim1` and `mod_dim2`).
#    - It defines the architecture using multiple convolutional layers (`inconv`, `down`, `up`, `outconv`) and includes the DCS subnetwork (`dcs0`, `dcs1`) for clustering.
#    - The `forward` method specifies the flow of data through the network.
#
# 4. `DCS` Class:
#    - Implements the Deep Clustering Subnetwork (DCS) architecture for clustering the image features.
#    - The `_l2norm` method is used to perform L2 normalization on input tensor.
#    - The `__init__` method initializes the DCS architecture with given input dimensions (`c`, `k`) and a specified number of stages (`stage_num`).
#    - The `forward` method performs the forward pass through the DCS subnetwork, implementing the iterative expectation-maximization algorithm.
#
# 5. `MyNet` Class:
#    - Defines a custom network that incorporates the UNet-like architecture with the DCS subnetwork (`emau`).
#
# 6. `Args` Object:
#    - Defines a class to hold various configurable arguments for the training process.
#
# 7. `get_filelist` Function:
#    - Retrieves a list of file paths within a directory.
#
# 8. `run` Function:
#    - This function performs the training and segmentation process for an input image.
#    - Initializes the necessary variables and loads the input image.
#    - Utilizes the DCS subnetwork to iteratively refine the segmentation using expectation-maximization.
#    - Displays the segmentation progress using OpenCV and updates the result image.
#
# 9. `mainf` Function:
#    - Calls the `run` function for each image in a specified directory and calculates the average time taken for segmentation.
#
# 10. `if __name__ == '__main__':` Block:
#     - Calls the `mainf` function when the script is run directly.
#
# 11. Epoch- Assign the balanced epoch value to avoid the overfitting and thus improve the preformance as well

# %% [markdown]
# # Implementation
# ********************************************************************************************************************
# #### PART - 1: Installing necessary library and Importing it
# #### PART - 2: Denormalization Function (denormalizeimage)
# #### PART - 3: UNet Architecture (UNet Class)
# #### PART - 4: DCS Architecture (DCS Class)
# #### PART - 5: Custom Network Architecture (MyNet Class)
# #### PART - 6: Argument Configuration (Args Class)
# #### PART - 7: Function to Get List of Files (get_filelist)
# #### PART - 8: run Function
# #### PART - 9: Main Function (mainf) and Main Execution

# %% [markdown]
# ### PART - 1: Installing necessary library and Importing it
#
# Installing the necessary libraries for performing image segmentation, including OpenCV (cv2), NumPy, and PyTorch

# %% [markdown]
# #### NECESSARY LIBRARIES

# %%
pip install torch torchvision torchaudio
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\shels\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\shels\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\shels\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\shels\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\shels\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\shels\anaconda3\lib\site-packages)

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\shels\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\shels\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\shels\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\shels\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\shels\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\shels\anaconda3\lib\site-packages)

# %% [markdown]
# #### Importing the library required for the implementation

# %%
import os
import time

import cv2
import numpy as np
from skimage import segmentation
import math
import torch
import torch.nn as nn
from torch.nn.modules.batchnorm import _BatchNorm
import torch.nn.functional as F
from scipy.io import loadmat,savemat
from unet_model import *
import matplotlib.pyplot as plt

mark_boundaries = segmentation.mark_boundaries

# %% [markdown]
# #### PART - 2: Denormalization Function (denormalizeimage)
# This function is used to reverse the normalization applied to the images before they are displayed. It takes tensor images and denormalizes them to their original values.

# %%
def denormalizeimage(images, mean=(0., 0., 0.), std=(1., 1., 1.)):
    """Denormalize tensor images with mean and standard deviation.
    Args:
        images (tensor): N*C*H*W
        mean (tuple): means for each channel.
        std (tuple): standard deviations for each channel.
    """
    images = images.cpu().numpy()
    # N*C*H*W to N*H*W*C
    images = images.transpose((0,2,3,1))
    images *= std
    images += mean
    images *=255.0
    # N*H*W*C to N*C*H*W
    images = images.transpose((0,3,1,2))
    return torch.tensor(images)

# %%
class UNet(nn.Module):
    def __init__(self, inp_dim, mod_dim1, mod_dim2):
        super(UNet, self).__init__()
        self.inc = inconv(inp_dim, 64)
        self.down1 = down(64, 128)
        self.up4 = up(192, 128)
        self.dcs0 = DCS(128, 32, 3)
        self.outc = outconv(128, mod_dim2)
        self.dcs1 = DCS(mod_dim2, 32, 3)


    def forward(self, x):
        x1 = self.inc(x)
        x2 = self.down1(x1)
        x = self.up4(x2, x1)
        x = self.outc(x)
        x, mu = self.dcs1(x)
        return x

# %% [markdown]
# ### DCS Architecture (DCS Class)
# The DCS class defines the Deep Clustering Subnetwork architecture. This subnetwork consists of multiple convolutional layers, L2 normalization steps, and iterations for updating cluster centers. It is designed to refine the features of the segmented regions.

# %%
class DCS(nn.Module):
    '''The Deep Clustering Subnetwork (DCS).
    Arguments:
        c (int): The input and output channel number.
        k (int): The number of cluster centers.
        stage_num (int): The iteration number for EM.
    '''
    
    def __init__(self, c, k, stage_num=3):
        super(DCS, self).__init__()
        self.stage_num = stage_num

        mu = torch.Tensor(1, c, k)  #
        mu.normal_(0, math.sqrt(2. / k))  #
        mu = self._l2norm(mu, dim=1)
        self.register_buffer('mu', mu)

        self.conv1 = nn.Conv2d(c, c, 1)
        self.conv2 =nn.Conv2d(c, c, 1, bias=False)

        ####iteration
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
            elif isinstance(m, _BatchNorm):
                m.weight.data.fill_(1)
                if m.bias is not None:
                    m.bias.data.zero_()

    def forward(self, x):
        idn = x
        # The first 1x1 conv
        x = self.conv1(x)

        b, c, h, w = x.size()
        x = x.view(b, c, h * w)
        mu = self.mu.repeat(b, 1, 1)  # b * c * k
        with torch.no_grad():
            for i in range(self.stage_num):
                x_t = x.permute(0, 2, 1)  # b * n * c
                z = torch.bmm(x_t, mu)  # b * n * k
                z = F.softmax(z, dim=2)  # b * n * k
                z_ = z / (1e-6 + z.sum(dim=1, keepdim=True))
                mu = torch.bmm(x, z_)
                mu = self._l2norm(mu, dim=1)

        z_t = z.permute(0, 2, 1)  # b * k * n
        x = mu.matmul(z_t)  # b * c * n
        x = x.view(b, c, h, w)  # b * c * h * w
        x = F.relu(x, inplace=True)

        # The second 1x1 conv
        x = self.conv2(x)
        x = x + idn #
        x = F.relu(x, inplace=True)

        return x, mu

    def _l2norm(self, inp, dim):
        '''Normlize the inp tensor with l2-norm.

        Returns a tensor where each sub-tensor of input along the given dim is
        normalized such that the 2-norm of the sub-tensor is equal to 1.

        Arguments:
            inp (tensor): The inp
            ut tensor.
            dim (int): The dimension to slice over to get the ssub-tensors.

        Returns:
            (tensor) The normalized tensor.
        '''
        return inp / (1e-6 + inp.norm(dim=dim, keepdim=True))

# %% [markdown]
# ### Argument Configuration (Args Class)
# Below class defines a set of arguments for controlling the training process, including the number of training epochs, input dimensions, GPU ID, and more.

# %%
class Args(object):
    train_epoch =80 ## training iteration T ##
    mod_dim1 = 64  #
    mod_dim2 =100 #
    gpu_id =0 #0
    min_label_num = 4  # if the label number small than it, break loop
    max_label_num = 256  # if the label number small than it, start to show result image.

# %% [markdown]
# ### Custom Network Architecture (MyNet Class)
# Below class defines a custom network architecture for further refining features. It includes convolutional layers and a DCS layer (emau).

# %%
class MyNet(nn.Module):
    def __init__(self, inp_dim, mod_dim1, mod_dim2):
        super(MyNet, self).__init__()

        self.seq = nn.Sequential(
            nn.Conv2d(inp_dim, mod_dim1, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(mod_dim1),
            nn.ReLU(inplace=True),
            nn.Conv2d(mod_dim1, mod_dim2, kernel_size=1, stride=1, padding=0),
            nn.BatchNorm2d(mod_dim2),
            nn.ReLU(inplace=True),
            nn.Conv2d(mod_dim2, mod_dim1, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(mod_dim1),
            nn.ReLU(inplace=True),
            nn.Conv2d(mod_dim1, mod_dim2, kernel_size=1, stride=1, padding=0),
            nn.BatchNorm2d(mod_dim2),
        )
        self.emau = DCS(mod_dim2, 64, 3)

    def forward(self, x):
        x=self.seq(x)
        return x

# %% [markdown]
# ### Function to Get List of Files (get_filelist)
# Below function recursively obtains a list of files from a given directory.

# %%
def get_filelist(dir, Filelist):

    newDir = dir

    if os.path.isfile(dir):

        Filelist.append(dir)

    elif os.path.isdir(dir):
        for s in os.listdir(dir):
            newDir = os.path.join(dir, s)
            get_filelist(newDir, Filelist)

    return Filelist

# %% [markdown]
# ### 'Run' Function
# This function represents the main image segmentation process. It loads the input image from folder called 'image' and its corresponding superpixel segmentation, initializes the network and optimizer, performs training iterations, and shows and saves intermediate segmentation results into the folder called 'output'

# %%
def run(name,namep):
    start_time0 = time.time()
    args = Args()
    pathbsd='./image\\'
    torch.cuda.manual_seed_all(1943)
    np.random.seed(1943)
    os.environ['CUDA_VISIBLE_DEVICES'] = str(args.gpu_id)  # choose GPU:0
    input_image_path = pathbsd + name
    image = cv2.imread(input_image_path)

    softmax = nn.Softmax(dim=1)

    '''segmentation ML'''
    m = loadmat('./superpixel/'+namep+'.mat');
    seglab = m["seg_lab"]

    seg_map=seglab
    show = mark_boundaries(image, seg_map)
    seg_map = seg_map.flatten()
    seg_lab = [np.where(seg_map == u_label)[0]
               for u_label in np.unique(seg_map)]

    '''train init'''
    device = torch.device("cuda" if torch.cuda.is_available() else 'cpu')

    tensor = image.transpose((2, 0, 1))
    tensor = tensor.astype(np.float32) / 255.0
    tensor = tensor[np.newaxis, :, :, :]
    tensor = torch.from_numpy(tensor).to(device)
    model = UNet(inp_dim=3, mod_dim1=args.mod_dim1, mod_dim2=args.mod_dim2).to(device)
    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=5e-2, momentum=0.9)
    image_flatten = image.reshape((-1, 3))
    color_avg = np.random.randint(255, size=(args.max_label_num, 3))
    show = image

    '''train loop'''
    start_time1 = time.time()
    model.train()
    for batch_idx in range(args.train_epoch):
        '''forward'''
        optimizer.zero_grad()
        output = model(tensor)[0]
        output1=output
        output1 = output1[np.newaxis, :, :, :]
        output2= output[0:1, :, :]
        croppings = (output2 > 0).float()

        output = output.permute(1, 2, 0).view(-1, args.mod_dim2)
        target = torch.argmax(output, 1)
        im_target = target.data.cpu().numpy()

        '''refine'''
        for inds in seg_lab:
            u_labels, hist = np.unique(im_target[inds], return_counts=True)
            im_target[inds] = u_labels[np.argmax(hist)]

        '''backward'''
        target = torch.from_numpy(im_target)
        target = target.to(device)

        loss = criterion(output, target) #as defined in Eq. (8)

        loss.backward()
        optimizer.step()

        '''show image''' #to print using the pesudo color;
        un_label, lab_inverse = np.unique(im_target, return_inverse=True, )
        if un_label.shape[0] < args.max_label_num:  # update show
            img_flatten = image_flatten.copy()
            if len(color_avg) != un_label.shape[0]:
                color_avg = [np.mean(img_flatten[im_target == label], axis=0, dtype=np.int) for label in un_label]
            for lab_id, color in enumerate(color_avg):
                img_flatten[lab_inverse == lab_id] = color
            show = img_flatten.reshape(image.shape)
        cv2.imshow("seg_pt", show)
        cv2.waitKey(1)
        print(loss.item())
        if len(un_label) < args.min_label_num:
            break

    '''save'''
    sp=list(image.shape)
    label = im_target.reshape((sp[0],sp[1]))

    time0 = time.time() - start_time0
    time1 = time.time() - start_time1

    print('PyTorchInit: %.2f\nTimeUsed: %.2f' % (time0, time1))
    cv2.imwrite("output/seg_%s_%ds.jpg" % (namep, time1), show)
    return time1

# %% [markdown]
# ### Main Function (mainf)
# The main function iterates through a list of images, calling the run function for each image to perform image segmentation. It calculates and outputs the average time taken for segmentation.

# %%
def mainf():
    dir='./image\\'
    LIst=get_filelist(dir, [])
    print(LIst)
    ST=0
    for ii in range(len(LIst)-1):
        name=LIst[ii][8:]
        print(name)
        namep=name[:-4]
        print(namep)
        time=run(name,namep)
        print(time)
        ST=ST+time
    print(ST/300)


if __name__ == '__main__':
    mainf()
# Out:
# ['./image\\2092.jpg', './image\\3096.jpg', './image\\8023.jpg', './image\\8049.jpg']
# 2092.jpg
# 2092
# C:\Users\shels\AppData\Local\Temp\ipykernel_8748\1641797497.py:72: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   color_avg = [np.mean(img_flatten[im_target == label], axis=0, dtype=np.int) for label in un_label]
# 4.327024936676025
# 4.109111785888672
# 3.8951404094696045
# 3.6183953285217285
# 3.4992382526397705
# 3.290435791015625
# 3.1545231342315674
# 2.926410675048828
# 2.735894203186035
# 2.4531800746917725
# 2.2391679286956787
# ...

# %% [markdown]
# ## Result
# #### Output - Images before and after the implementation

# %% [markdown]
# As mentioned above, the Input image used in the experiment are from the image folder. Then after the image segmentation implementation, the image will be stored to the output folder. Therefore we will display the before and after image.

# %%
import cv2
import os
import matplotlib.pyplot as plt

# Function to load and display images from folders side by side
def display_images(image_folder, output_folder):
    # Get the list of image files in the folders
    image_files = os.listdir(image_folder)
    output_files = os.listdir(output_folder)
    
    # Sort the files to ensure corresponding images are displayed together
    image_files.sort()
    output_files.sort()
    
    # Iterate through the images and display them side by side
    for img_file, out_file in zip(image_files, output_files):
        # Read the images
        img_path = os.path.join(image_folder, img_file)
        out_path = os.path.join(output_folder, out_file)
        img = cv2.imread(img_path)
        out_img = cv2.imread(out_path)
        
        # Convert images to RGB format for display
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        out_img_rgb = cv2.cvtColor(out_img, cv2.COLOR_BGR2RGB)
        
        # Display images side by side
        fig, axes = plt.subplots(1, 2, figsize=(12, 6))
        axes[0].imshow(img_rgb)
        axes[0].set_title('Original Image')
        axes[0].axis('off')
        axes[1].imshow(out_img_rgb)
        axes[1].set_title('Segmented image')
        axes[1].axis('off')
        plt.show()

# Call the function with the folder paths
image_folder = 'image'
output_folder = 'output'
display_images(image_folder, output_folder)

# %% [markdown]
# ### Observation

# %% [markdown]
# As per the above result, each object in the images are segmented with different colours to easily differentiate it. This helps to identify the each object in images. However, in some part of the images are not clustered properly so there is place of improvement in it

# %% [markdown]
# ## Contribution Code

# %% [markdown]
# ### Contribution: Introduced Segment Anything Model (SAM) model to the experimentation process

# %%
# !pip install tf-keras
# Out:
# ...
#      ---------------------------------------- 1.7/1.7 MB 7.8 MB/s eta 0:00:00
# ...
#   Using cached tensorflow-2.16.1-cp310-cp310-win_amd64.whl (2.1 kB)
# ...
#   Using cached keras-3.2.1-py3-none-any.whl (1.1 MB)
# ...
#   Attempting uninstall: keras
#     Found existing installation: Keras 2.3.1
#     Uninstalling Keras-2.3.1:
#       Successfully uninstalled Keras-2.3.1
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.13.0
#     Uninstalling tensorflow-2.13.0:
#       Successfully uninstalled tensorflow-2.13.0
# ...
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\shels\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\shels\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\shels\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\shels\anaconda3\lib\site-packages)
# ...

# %%
from tensorflow import keras
from transformers import TFSamModel, SamProcessor
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.python.ops.numpy_ops import np_config
from PIL import Image
import requests
import glob
import os
# Out:
# WARNING:tensorflow:From C:\Users\shels\anaconda3\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
model = TFSamModel.from_pretrained("facebook/sam-vit-base")
processor = SamProcessor.from_pretrained("facebook/sam-vit-base")
# Out:
# model.safetensors:   0%|          | 0.00/375M [00:00<?, ?B/s]
# WARNING:tensorflow:From C:\Users\shels\anaconda3\lib\site-packages\tf_keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# All PyTorch model weights were used when initializing TFSamModel.
#
# All the weights of TFSamModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFSamModel for predictions without further training.
# C:\Users\shels\anaconda3\lib\site-packages\torchvision\io\image.py:13: UserWarning: Failed to load image Python extension: '[WinError 127] The specified procedure could not be found'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
# ...

# %%
np_config.enable_numpy_behavior()


def show_mask(mask, ax, random_color=False):
    if random_color:
        color = np.concatenate([np.random.random(3), np.array([0.6])], axis=0)
    else:
        color = np.array([30 / 255, 144 / 255, 255 / 255, 0.6])
    h, w = mask.shape[-2:]
    mask_image = mask.reshape(h, w, 1) * color.reshape(1, 1, -1)
    ax.imshow(mask_image)


def show_box(box, ax):
    x0, y0 = box[0], box[1]
    w, h = box[2] - box[0], box[3] - box[1]
    ax.add_patch(
        plt.Rectangle((x0, y0), w, h, edgecolor="green", facecolor=(0, 0, 0, 0), lw=2)
    )


def show_boxes_on_image(raw_image, boxes):
    plt.figure(figsize=(10, 10))
    plt.imshow(raw_image)
    for box in boxes:
        show_box(box, plt.gca())
    plt.axis("on")
    plt.show()


def show_points_on_image(raw_image, input_points, input_labels=None):
    plt.figure(figsize=(10, 10))
    plt.imshow(raw_image)
    input_points = np.array(input_points)
    if input_labels is None:
        labels = np.ones_like(input_points[:, 0])
    else:
        labels = np.array(input_labels)
    show_points(input_points, labels, plt.gca())
    plt.axis("on")
    plt.show()


def show_points_and_boxes_on_image(raw_image, boxes, input_points, input_labels=None):
    plt.figure(figsize=(10, 10))
    plt.imshow(raw_image)
    input_points = np.array(input_points)
    if input_labels is None:
        labels = np.ones_like(input_points[:, 0])
    else:
        labels = np.array(input_labels)
    show_points(input_points, labels, plt.gca())
    for box in boxes:
        show_box(box, plt.gca())
    plt.axis("on")
    plt.show()


def show_points_and_boxes_on_image(raw_image, boxes, input_points, input_labels=None):
    plt.figure(figsize=(10, 10))
    plt.imshow(raw_image)
    input_points = np.array(input_points)
    if input_labels is None:
        labels = np.ones_like(input_points[:, 0])
    else:
        labels = np.array(input_labels)
    show_points(input_points, labels, plt.gca())
    for box in boxes:
        show_box(box, plt.gca())
    plt.axis("on")
    plt.show()


def show_points(coords, labels, ax, marker_size=375):
    pos_points = coords[labels == 1]
    neg_points = coords[labels == 0]
    ax.scatter(
        pos_points[:, 0],
        pos_points[:, 1],
        color="green",
        marker="*",
        s=marker_size,
        edgecolor="white",
        linewidth=1.25,
    )
    ax.scatter(
        neg_points[:, 0],
        neg_points[:, 1],
        color="red",
        marker="*",
        s=marker_size,
        edgecolor="white",
        linewidth=1.25,
    )


def show_masks_on_image(raw_image, masks, scores):
    if len(masks[0].shape) == 4:
        final_masks = tf.squeeze(masks[0])
    if scores.shape[0] == 1:
        final_scores = tf.squeeze(scores)

    nb_predictions = scores.shape[-1]
    fig, axes = plt.subplots(1, nb_predictions, figsize=(15, 15))

    for i, (mask, score) in enumerate(zip(final_masks, final_scores)):
        mask = tf.stop_gradient(mask)
        axes[i].imshow(np.array(raw_image))
        show_mask(mask, axes[i])
        axes[i].title.set_text(f"Mask {i+1}, Score: {score.numpy().item():.3f}")
        axes[i].axis("off")
    plt.show()

# %%
def runModified(name,namep):
    start_time0 = time.time()
    # Folder path containing the images
    folder_path = "./image\\"

    # Get a list of all image files in the folder
    image_files = [f for f in os.listdir(folder_path) if f.lower().endswith((".png", ".jpg", ".jpeg"))]

    # Load and display each image
    for image_file in image_files:
        image_path = os.path.join(folder_path, image_file)
        raw_image = Image.open(image_path).convert("RGB")
        start_time1 = time.time()
        input_points = [[[450, 600]]]

        # Visualize a single point.
        show_points_on_image(raw_image, input_points[0])

        # Preprocess the input image.
        inputs = processor(raw_image, input_points=input_points, return_tensors="tf")

        # Predict for segmentation with the prompt.
        outputs = model(**inputs)

        # Post-process masks
        masks = processor.image_processor.post_process_masks(
            outputs.pred_masks,
            inputs["original_sizes"],
            inputs["reshaped_input_sizes"],
            return_tensors="tf",
        )
        show_masks_on_image(raw_image, masks, outputs.iou_scores)
    time0 = time.time() - start_time0
    time1 = time.time() - start_time1
    print('PyTorchInit: %.2f\nTimeUsed: %.2f' % (time0, time1))
    return time1

# %%
def mainf():
    dir='./image\\'
    LIst=get_filelist(dir, [])
    print(LIst)
    ST=0
    
    
    for ii in range(len(LIst)-1):
        name=LIst[ii][8:]
        print(name)
        namep=name[:-4]
        print(namep)    
        
    time=runModified(name,namep)


if __name__ == '__main__':
    mainf()
# Out:
# ['./image\\0001.png', './image\\3096.jpg', './image\\8049.jpg']
# 0001.png
# 0001
# 3096.jpg
# 3096
# PyTorchInit: 23.69
# TimeUsed: 6.76

# %% [markdown]
# ## Conclusion and Future Direction
# *******************************************************************************************************************************
#
# #### Learnings :
# This is a great learning for working on image segmentation project and related models. Comparing the Deep Image Clustering (DIC) framework using u-net and the Segment Anything Model (SAM) reveals diverse approaches to segmentation where DIC focuses on deep learning techniques for unsupervised segmentation, while SAM employs zero-shot learning and domain generalization. DIC typically requires data for training, whereas SAM operates on a pre-trained dataset, reducing the need for specific labels. SAM offers ease of use and deployment with its ability to segment objects without retraining, while DIC may require fine-tuning and incurs higher computational costs, highlighting considerations for practical implementation.
#
# #### Results Discussion :
#
# Based on result by DIC using U-net model, each object in the images are segmented with different colours to easily differentiate it. This helps to identify the each object in images. However, in some part of the images are not clustered properly so there is place of improvement in it. Wherelse, the SAM can precisely identify the location of specific objects within an image or segment all objects presents with score as well.
#
# In contrast to SAM, which uses a pre-trained dataset to speed up segmentation and lessen the requirement for specific labels, DIC relies on data for training. Because SAM can segment objects without retraining, it offers a more basic method in terms of simplicity of use and deployment, despite the gap in training needs. Moreover, the computational costs associated with each model differ significantly. DIC's iterative training process and potential parameter tuning incur higher computational overheads compared to SAM's pre-trained architecture. This aspect is crucial for practical implementation, especially in resource-constrained environments.
#
# The segmentation performance of both models depends on various factors, including dataset characteristics, model complexity, and generalization capabilities. DIC's deep learning approach allows for intricate feature extraction and clustering, potentially yielding high segmentation accuracy. Meanwhile, SAM's domain generalization enables it to segment objects across diverse domains without additional training, offering robust performance in various scenarios.
#
#
# ### Limitations :
# #### Deep Image Clustering (DIC) using U-net:
#
# The iterative nature of DIC's training process and potential parameter tuning can lead to high computational costs, particularly for large datasets or complex models. DIC's performance may be sensitive to the selection of hyperparameters, such as clustering thresholds. While DIC may generalize to some extent across different datasets, it may require retraining or fine-tuning for optimal performance
#
# #### Segment Anything Model (SAM):
#
#  SAM relies on a pre-trained dataset (SA-1B) for its segmentation capabilities, which may limit its adaptability to new or emerging object categories not included in the training data. It reliance on pre-trained data and potentially complex inference processes may require significant computational resources for deployment, which could pose challenges in resource-constrained environments.
#
#
# ### Future Extension :
#
#
# By addressing these future extensions, both DIC and SAM can further enhance their capabilities, applicability, and performance, paving the way for advancements in unsupervised image segmentation and object segmentation across diverse domains. Future extensions for the Deep Image Clustering (DIC) framework and the Segment Anything Model (SAM) could involve incorporating weak supervision techniques into DIC to reduce the reliance on fully labeled data, exploring advanced clustering algorithms to handle complex image structures in DIC, and enhancing DIC's scalability for large-scale datasets. Additionally, DIC could benefit from the development of domain adaptation methods to improve its generalization across diverse datasets. For SAM, potential future directions include enabling continual learning capabilities to adapt to new object categories over time, enhancing interpretability through attention mechanisms or visualization techniques, and exploring transfer learning extensions to adapt the pre-trained model to specific domains or tasks with limited labeled data. Furthermore, optimizing SAM's inference process for resource-constrained environments through model compression or efficient hardware accelerators could improve its deployment efficiency. These future extensions aim to advance unsupervised image segmentation and object segmentation across diverse domains, enhancing their capabilities and applicability.

# %% [markdown]
#   # References:
#
# 1. L. Zhou and W. Wei, "DIC: Deep Image Clustering for Unsupervised Image Segmentation," in IEEE Access, vol. 8, pp. 34481-34491, 2020, doi: 10.1109/ACCESS.2020.2974496.
#
#
# 2. T. Kanungo, D. M. Mount, N. S. Netanyahu, C. D. Piatko, R. Silverman and A. Y. Wu, "An efficient k-means clustering algorithm: analysis and implementation," in IEEE Transactions on Pattern Analysis and Machine Intelligence, vol. 24, no. 7, pp. 881-892, July 2002, doi: 10.1109/TPAMI.2002.1017616.
#
#
# 3. C. Carson, S. Belongie, H. Greenspan and J. Malik, "Blobworld: image segmentation using expectation-maximization and its application to image querying," in IEEE Transactions on Pattern Analysis and Machine Intelligence, vol. 24, no. 8, pp. 1026-1038, Aug. 2002, doi: 10.1109/TPAMI.2002.1023800.
#
#
# 4. Jianbo Shi and J. Malik, "Normalized cuts and image segmentation," in IEEE Transactions on Pattern Analysis and Machine Intelligence, vol. 22, no. 8, pp. 888-905, Aug. 2000, doi: 10.1109/34.868688.
#
#
# 5. D. Comaniciu and P. Meer, "Mean shift: a robust approach toward feature space analysis," in IEEE Transactions on Pattern Analysis and Machine Intelligence, vol. 24, no. 5, pp. 603-619, May 2002, doi: 10.1109/34.1000236.
#
#
# 6. L. Grady, "Random Walks for Image Segmentation," in IEEE Transactions on Pattern Analysis and Machine Intelligence, vol. 28, no. 11, pp. 1768-1783, Nov. 2006, doi: 10.1109/TPAMI.2006.233.
#
#
# 7. J. Long, E. Shelhamer and T. Darrell, "Fully convolutional networks for semantic segmentation," 2015 IEEE Conference on Computer Vision and Pattern Recognition (CVPR), Boston, MA, USA, 2015, pp. 3431-3440, doi: 10.1109/CVPR.2015.7298965.
#
#
# 8. S. Zheng et al., "Conditional Random Fields as Recurrent Neural Networks," 2015 IEEE International Conference on Computer Vision (ICCV), Santiago, Chile, 2015, pp. 1529-1537, doi: 10.1109/ICCV.2015.179.
#
#
# 9. L. -C. Chen, J. T. Barron, G. Papandreou, K. Murphy and A. L. Yuille, "Semantic Image Segmentation with Task-Specific Edge Detection Using CNNs and a Discriminatively Trained Domain Transform," 2016 IEEE Conference on Computer Vision and Pattern Recognition (CVPR), Las Vegas, NV, USA, 2016, pp. 4545-4554, doi: 10.1109/CVPR.2016.492.
#
#
# 10. M. Donoser, M. Urschler, M. Hirzer and H. Bischof, "Saliency driven total variation segmentation," 2009 IEEE 12th International Conference on Computer Vision, Kyoto, Japan, 2009, pp. 817-824, doi: 10.1109/ICCV.2009.5459296.
#
#
# 11. M. B. Salah, A. Mitiche and I. B. Ayed, "Multiregion Image Segmentation by Parametric Kernel Graph Cuts," in IEEE Transactions on Image Processing, vol. 20, no. 2, pp. 545-557, Feb. 2011, doi: 10.1109/TIP.2010.2066982.
#
#
# 12. P. Arbeláez, J. Pont-Tuset, J. Barron, F. Marques and J. Malik, "Multiscale Combinatorial Grouping," 2014 IEEE Conference on Computer Vision and Pattern Recognition, Columbus, OH, USA, 2014, pp. 328-335, doi: 10.1109/CVPR.2014.49.
#
#
# 13. X. Fu, C. -Y. Wang, C. Chen, C. Wang and C. . -C. J. Kuo, "Robust Image Segmentation Using Contour-Guided Color Palettes," 2015 IEEE International Conference on Computer Vision (ICCV), Santiago, Chile, 2015, pp. 1618-1625, doi: 10.1109/ICCV.2015.189.
#
#
# 14. Y. LeCun et al., "Backpropagation Applied to Handwritten Zip Code Recognition," in Neural Computation, vol. 1, no. 4, pp. 541-551, Dec. 1989, doi: 10.1162/neco.1989.1.4.541.
#
#
# 15. H. Noh, S. Hong and B. Han, "Learning Deconvolution Network for Semantic Segmentation," 2015 IEEE International Conference on Computer Vision (ICCV), Santiago, Chile, 2015, pp. 1520-1528, doi: 10.1109/ICCV.2015.178.
#
#
# 16. W. Song, N. Zheng, X. Liu, L. Qiu and R. Zheng, "An Improved U-Net Convolutional Networks for Seabed Mineral Image Segmentation," in IEEE Access, vol. 7, pp. 82744-82752, 2019, doi: 10.1109/ACCESS.2019.2923753.
#
#
# 17. N. Xu, B. Price, S. Cohen, J. Yang and T. Huang, "Deep Interactive Object Selection," 2016 IEEE Conference on Computer Vision and Pattern Recognition (CVPR), Las Vegas, NV, USA, 2016, pp. 373-381, doi: 10.1109/CVPR.2016.47.
#
#
# 18. K. . -K. Maninis, S. Caelles, J. Pont-Tuset and L. Van Gool, "Deep Extreme Cut: From Extreme Points to Object Segmentation," 2018 IEEE/CVF Conference on Computer Vision and Pattern Recognition, Salt Lake City, UT, USA, 2018, pp. 616-625, doi: 10.1109/CVPR.2018.00071.
#
#
# 19. W. -D. Jang and C. -S. Kim, "Interactive Image Segmentation via Backpropagating Refinement Scheme," 2019 IEEE/CVF Conference on Computer Vision and Pattern Recognition (CVPR), Long Beach, CA, USA, 2019, pp. 5292-5301, doi: 10.1109/CVPR.2019.00544.
#
#
# 20. V. Lempitsky, A. Vedaldi and D. Ulyanov, "Deep Image Prior," 2018 IEEE/CVF Conference on Computer Vision and Pattern Recognition, Salt Lake City, UT, USA, 2018, pp. 9446-9454, doi: 10.1109/ICCV.2011.6126343.
#
# 21. Alexander Kirillov, Eric Mintun, Nikhila Ravi, Hanzi Mao, Chloé Rolland, Laura Gustafson, Tete Xiao, Spencer Whitehead, Alexander C. Berg, Wan-Yen Lo, Piotr Dollár, Ross B. Girshick: Segment Anything. ICCV 2023: 3992-4003.
#
# 22. https://github.com/facebookresearch/segment-anything
